# %% [markdown]
# <a href="https://colab.research.google.com/github/SakiB424414/Event-Management-System/blob/main/Event_Management_System.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

data = {'Name': ['Yousuf', 'Sakib', 'Riyad'],
        'Email': ['abuyousuf67@sust.edu', 'ashiqur27@sust.edu', 'mdriyad52@gmail.com'],
        'City' : ['Gaibandha', 'Jashore', 'Gazipur'],
        'Dept' : ['OCG', 'OCG', 'OCG'],
        'age': [24,24,25]}
df = pd.DataFrame(data)
df['Country'] = ['Bangladesh', 'Bangladesh', 'Bangladesh']
df = df.drop(columns=['age'])
df['age'] = ['24', '26', '24']

df
# Out:
#      Name                 Email       City Dept     Country age
# 0  Yousuf  abuyousuf67@sust.edu  Gaibandha  OCG  Bangladesh  24
# 1   Sakib    ashiqur27@sust.edu    Jashore  OCG  Bangladesh  26
# 2   Riyad   mdriyad52@gmail.com    Gazipur  OCG  Bangladesh  24
